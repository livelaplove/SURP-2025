# %% [markdown]
# # Metallicity Histogram for All-prot Without and With Kinematic Data & xgboost

# %%
import fix

def nokinematichistogram():
    csv = 'tempcsv/prot_kinematic_xgboost.csv'
    x = 'mh_xgboost'
    nbins = 350
    title = f'Binned Metallicities for Non-Kinematic Data ({nbins} Bins)'

    fix.histogram(csv, x, nbins, title, figsize=(12,6))

    

def kinematichistogram():
    # used to create data file with xgboost metallicities
    # fix.writecsv('table-1.csv', 'All_prot_kin.csv', 'source_id', 'source_id', 'tempcsv/prot_kinematic_xgboost.csv')

    csv = 'tempcsv/prot_kinematic_xgboost.csv'
    x = 'mh_xgboost'
    nbins = 350
    title = f'Binned Metallicities for Kinematic Data ({nbins} Bins)'

    fix.histogram(csv, x, nbins, title, figsize=(12,6))
    

    nbins = 100
    title = f'Binned Metallicities for Kinematic Data ({nbins} Bins)'
    fix.histogram(csv, x, nbins, title, figsize=(12,6))


nokinematichistogram()
kinematichistogram()
